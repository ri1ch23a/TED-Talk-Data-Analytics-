# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('data.csv'):
    for filename in filenames:
        print(os.path.join(dirname,filename))

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.isnull().sum()
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.values
# Out:
# array([['Climate action needs new frontline leadership',
#         'Ozawa Bineshi Albert', 'December 2021', 404000, 12000,
#         'https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership'],
#        ['The dark history of the overthrow of Hawaii', 'Sydney Iaukea',
#         'February 2022', 214000, 6400,
#         'https://ted.com/talks/sydney_iaukea_the_dark_history_of_the_overthrow_of_hawaii'],
#        ['How play can spark new ideas for your business',
#         'Martin Reeves', 'September 2021', 412000, 12000,
#         'https://ted.com/talks/martin_reeves_how_play_can_spark_new_ideas_for_your_business'],
#        ...,
#        ['Greening the ghetto', 'Majora Carter', 'February 2006', 2900000,
#         88000, 'https://ted.com/talks/majora_carter_greening_the_ghetto'],
#        ['Simplicity sells', 'David Pogue', 'February 2006', 2000000,
#         60000, 'https://ted.com/talks/david_pogue_simplicity_sells'],
# ...

# %%
len(df.values)
# Out:
# 5439

# %%
data=df.values

# %%
data
# Out:
# array([['Climate action needs new frontline leadership',
#         'Ozawa Bineshi Albert', 'December 2021', 404000, 12000,
#         'https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership'],
#        ['The dark history of the overthrow of Hawaii', 'Sydney Iaukea',
#         'February 2022', 214000, 6400,
#         'https://ted.com/talks/sydney_iaukea_the_dark_history_of_the_overthrow_of_hawaii'],
#        ['How play can spark new ideas for your business',
#         'Martin Reeves', 'September 2021', 412000, 12000,
#         'https://ted.com/talks/martin_reeves_how_play_can_spark_new_ideas_for_your_business'],
#        ...,
#        ['Greening the ghetto', 'Majora Carter', 'February 2006', 2900000,
#         88000, 'https://ted.com/talks/majora_carter_greening_the_ghetto'],
#        ['Simplicity sells', 'David Pogue', 'February 2006', 2000000,
#         60000, 'https://ted.com/talks/david_pogue_simplicity_sells'],
# ...

# %%
data[0]
# Out:
# array(['Climate action needs new frontline leadership',
#        'Ozawa Bineshi Albert', 'December 2021', 404000, 12000,
#        'https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership'],
#       dtype=object)

# %%
data[5300]
# Out:
# array(['Aid for Africa? No thanks.', 'Andrew Mwenda', 'June 2007',
#        1300000, 41000,
#        'https://ted.com/talks/andrew_mwenda_aid_for_africa_no_thanks'],
#       dtype=object)

# %%
data[0][0]
# Out:
# 'Climate action needs new frontline leadership'

# %%
data[4][1]
# Out:
# 'Mahendra Singhi'

# %%
author=[]
for i in range(len(data)):
    print(data[i][1])
# Out:
# Ozawa Bineshi Albert
# Sydney Iaukea
# Martin Reeves
# James K. Thornton
# Mahendra Singhi
# Rosamund Adoo-Kissi-Debrah
# Iseult Gillespie
# Gay Gordon-Byrne
# Erin Meezan
# Dwan Reece
# Ian Kerner
# Richard Browning
# Daniel H. Pink
# Lucas Joppa
#  Belle and Sebastian
# Mounia Akl
# Yana Buhrer Tavanier
# Susan Ruffo
# Tim Dunn
#  Let It Happen
# Dave Matthews
# Zoë Karl-Waithaka
# Dan Kwartler
# Dan Jørgensen
# Lei Li
# Nick Turner and Whitney Pennington Rodgers
# Elizabeth Cox
#  Kaz
# Katie McGinty
# Rachel Kyte
# Katie Paterson
# Emily Zobel Marshall
# Deval Patrick
# Rha Goddess and Deepa Purushothaman
# Zac Goldsmith
# Thomas W. Cronin
# Gala Marija Vrbanic
# Li-Huei Tsai
# Emily Pilloton-Lam
# Dustin Burke
# Marie Brodsky
# Gabrielle Walker
# Reuben Jonathan Miller
# Iseult Gillespie
# Carlos M. Duarte
# Candace Parker
# Jenny Scheinman with Nels Cline and Todd Sickafoose
# Emma Bryce
# Jennifer Aaker and Naomi Bagdonas
# American Family Insurance
# Sam Hester
# ...

# %%
author=[]
for i in range(len(data)):
    author.append(data[i][1])

# %%
author
# Out:
# ['Ozawa Bineshi Albert',
#  'Sydney Iaukea',
#  'Martin Reeves',
#  'James K. Thornton',
#  'Mahendra Singhi',
#  'Rosamund Adoo-Kissi-Debrah',
#  'Iseult Gillespie',
#  'Gay Gordon-Byrne',
#  'Erin Meezan',
#  'Dwan Reece',
#  'Ian Kerner',
#  'Richard Browning',
#  'Daniel H. Pink',
#  'Lucas Joppa',
#  ' Belle and Sebastian',
#  'Mounia Akl',
#  'Yana Buhrer Tavanier',
#  'Susan Ruffo',
#  'Tim Dunn',
#  ' Let It Happen',
#  'Dave Matthews',
#  'Zoë Karl-Waithaka',
#  'Dan Kwartler',
#  'Dan Jørgensen',
#  'Lei Li',
#  'Nick Turner and Whitney Pennington Rodgers',
#  'Elizabeth Cox',
#  ' Kaz',
#  'Katie McGinty',
#  'Rachel Kyte',
#  'Katie Paterson',
#  'Emily Zobel Marshall',
#  'Deval Patrick',
#  'Rha Goddess and Deepa Purushothaman',
#  'Zac Goldsmith',
#  'Thomas W. Cronin',
#  'Gala Marija Vrbanic',
#  'Li-Huei Tsai',
#  'Emily Pilloton-Lam',
#  'Dustin Burke',
#  'Marie Brodsky',
#  'Gabrielle Walker',
#  'Reuben Jonathan Miller',
#  'Iseult Gillespie',
# ...

# %%
len(author)
# Out:
# 5439

# %%
author=set()
for i in range(len(data)):
    author.add(data[i][1])

# %%
len(author)
# Out:
# 4443

# %% [markdown]
# #### Total Number of Authors

# %%
author=set()
for i in range(len(data)):
     author.add(data[i][1])

print(len(author))
# Out:
# 4443

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
for i in range(len(data)):
    if(data[i][1]=='Bill Gates'):
        print(data[i])
# Out:
# ['The innovations we need to avoid a climate disaster' 'Bill Gates'
#  'March 2021' 1700000 53000
#  'https://ted.com/talks/bill_gates_the_innovations_we_need_to_avoid_a_climate_disaster']
# ['How the pandemic will shape the near future' 'Bill Gates' 'June 2020'
#  4600000 138000
#  'https://ted.com/talks/bill_gates_how_the_pandemic_will_shape_the_near_future']
# ['How we must respond to the coronavirus pandemic' 'Bill Gates'
#  'March 2020' 8600000 259000
#  'https://ted.com/talks/bill_gates_how_we_must_respond_to_the_coronavirus_pandemic']
# ["The next outbreak? We're not ready" 'Bill Gates' 'March 2015' 43000000
#  1300000
#  'https://ted.com/talks/bill_gates_the_next_outbreak_we_re_not_ready']
# ['Teachers need real feedback' 'Bill Gates' 'May 2013' 4500000 135000
#  'https://ted.com/talks/bill_gates_teachers_need_real_feedback']
# ['How state budgets are breaking US schools' 'Bill Gates' 'March 2011'
#  2100000 63000
# ...

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
if(data[i][3]):
        print(data[i][3])
# Out:
# 3600000

# %%
views=[]
for i in range(len(data)):
    views.append(data[i][3])
    print(data[i][3])
# Out:
# 404000
# 214000
# 412000
# 427000
# 2400
# 422000
# 412000
# 455000
# 66000
# 584000
# 87000
# 213000
# 622000
# 526000
# 23000
# 628000
# 459000
# 522000
# 96000
# 4500
# 1600
# 667000
# 456000
# 632000
# 97000
# 609000
# 363000
# 649000
# 134000
# 613000
# 817000
# 411000
# 700000
# 678000
# 30000
# 743000
# 669000
# 766000
# 789000
# 800000
# 601000
# 732000
# 751000
# 998000
# 786000
# 1000000
# 20000
# 2300000
# 1000000
# 10000
# 880000
# 1500000
# 19000
# 825000
# 90000
# 888000
# 839000
# 951000
# 761000
# 992000
# 861000
# 11000
# 1100000
# 864000
# 1100000
# 11000
# 724000
# 295000
# 1300000
# 1100000
# 969000
# 1000000
# 986000
# 837000
# 527000
# 1000000
# 1000000
# 311000
# 1200000
# 1000000
# 3800
# 1100000
# 1000000
# 1000000
# 1000000
# 981000
# 200000
# 2500
# 4900
# 1100000
# 635000
# 1000000
# 4000
# 1000000
# 1100000
# 315000
# 714000
# 1200000
# 1200000
# 1000000
# 1400000
# 1400000
# 475000
# 1300000
# 422000
# 315000
# 277000
# 1200000
# 357000
# 260000
# ...

# %% [markdown]
# ###### Total Number Of Views in all the Ted Talks

# %%
sum(views)
# Out:
# 11214972679

# %% [markdown]
# #### Average View  per Video On Ted Talk

# %%
int(sum(views)/len(data))
# Out:
# 2061954

# %% [markdown]
# ###### Average Number Of Views for Bill Gates

# %%
views=[]
for i in range(len(data)):
    if(data[i][1]=='Bill Gates'):
        views.append(data[i][3]) 
        print(int(sum(views)/len(data)))
# Out:
# 312
# 1158
# 2739
# 10645
# 11472
# 11858
# 13348
# 14304

# %%
for i in range(len(data)):
    print(data[i][3],data[i][4],int(data[i][3]/data[i][4]))
# Out:
# 404000 12000 33
# 214000 6400 33
# 412000 12000 34
# 427000 12000 35
# 2400 72 33
# 422000 12000 35
# 412000 12000 34
# 455000 13000 35
# 66000 1900 34
# 584000 17000 34
# 87000 2600 33
# 213000 6400 33
# 622000 18000 34
# 526000 15000 35
# 23000 690 33
# 628000 18000 34
# 459000 13000 35
# 522000 15000 34
# 96000 2900 33
# 4500 135 33
# 1600 49 32
# 667000 20000 33
# 456000 13000 35
# 632000 18000 35
# 97000 2900 33
# 609000 18000 33
# 363000 10000 36
# 649000 19000 34
# 134000 4000 33
# 613000 18000 34
# 817000 24000 34
# 411000 12000 34
# 700000 21000 33
# 678000 20000 33
# 30000 913 32
# 743000 22000 33
# 669000 20000 33
# 766000 23000 33
# 789000 23000 34
# 800000 24000 33
# 601000 18000 33
# 732000 21000 34
# 751000 22000 34
# 998000 29000 34
# 786000 23000 34
# 1000000 32000 31
# 20000 606 33
# 2300000 70000 32
# 1000000 32000 31
# 10000 312 32
# 880000 26000 33
# 1500000 47000 31
# 19000 580 32
# 825000 24000 34
# 90000 2700 33
# 888000 26000 34
# 839000 25000 33
# ...

# %%
view_to_like=[]
for i in range(len(data)):
     view_to_like.append(int(data[i][3]/data[i][4]))

# %%
view_to_like
# Out:
# [33,
#  33,
#  34,
#  35,
#  33,
#  35,
#  34,
#  35,
#  34,
#  34,
#  33,
#  33,
#  34,
#  35,
#  33,
#  34,
#  35,
#  34,
#  33,
#  33,
#  32,
#  33,
#  35,
#  35,
#  33,
#  33,
#  36,
#  34,
#  33,
#  34,
#  34,
#  34,
#  33,
#  33,
#  32,
#  33,
#  33,
#  33,
#  34,
#  33,
#  33,
#  34,
#  34,
#  34,
#  34,
#  31,
#  33,
#  32,
#  31,
#  32,
#  33,
#  31,
#  32,
#  34,
#  33,
#  34,
#  33,
#  33,
#  34,
#  34,
#  34,
#  32,
#  33,
#  34,
#  33,
#  33,
#  34,
#  33,
#  32,
#  33,
#  33,
#  33,
#  34,
#  33,
#  35,
#  31,
#  31,
#  33,
#  32,
#  33,
#  33,
#  33,
#  32,
#  31,
#  32,
#  33,
#  33,
#  32,
#  33,
#  32,
#  33,
#  31,
#  33,
#  31,
#  33,
#  33,
#  34,
#  33,
#  31,
#  31,
#  31,
#  31,
#  33,
#  31,
#  35,
#  33,
#  33,
#  33,
#  35,
#  33,
#  33,
#  33,
#  31,
#  33,
#  33,
#  33,
#  33,
#  33,
#  32,
#  35,
#  32,
#  33,
#  34,
#  33,
#  32,
#  34,
#  32,
#  33,
#  33,
#  33,
#  33,
#  34,
#  33,
#  33,
#  31,
#  31,
#  33,
#  33,
#  31,
#  35,
#  33,
#  31,
# ...

# %%
len(view_to_like)
# Out:
# 5439

# %%
max(view_to_like)
# Out:
# 36

# %%
min(view_to_like)
# Out:
# 30

# %%
df['vtl_ratio']=view_to_like
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_11064\2801869754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vtl_ratio']=view_to_like

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %% [markdown]
# #### Ted Talks Of Bill Gates

# %%
df['author']
# Out:
# 0       Ozawa Bineshi Albert
# 1              Sydney Iaukea
# 2              Martin Reeves
# 3          James K. Thornton
# 4            Mahendra Singhi
#                 ...
# 5435            Hans Rosling
# 5436        Sir Ken Robinson
# 5437           Majora Carter
# 5438             David Pogue
# 5439                 Al Gore
# Name: author, Length: 5439, dtype: object

# %%
df['author'] =='Bill Gates'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5435    False
# 5436    False
# 5437    False
# 5438    False
# 5439    False
# Name: author, Length: 5439, dtype: bool

# %%
df[df['author'] =='Bill Gates']
# Out:
#                                                   title      author  \
# 403   The innovations we need to avoid a climate dis...  Bill Gates
# 789         How the pandemic will shape the near future  Bill Gates
# 952     How we must respond to the coronavirus pandemic  Bill Gates
# 3251                 The next outbreak? We're not ready  Bill Gates
# 3878                        Teachers need real feedback  Bill Gates
# 4560          How state budgets are breaking US schools  Bill Gates
# 4824                                Innovating to zero!  Bill Gates
# 5062                   Mosquitos, malaria and education  Bill Gates
#
#                date     views    likes  \
# 403      March 2021   1700000    53000
# 789       June 2020   4600000   138000
# 952      March 2020   8600000   259000
# 3251     March 2015  43000000  1300000
# 3878       May 2013   4500000   135000
# 4560     March 2011   2100000    63000
# 4824  February 2010   8100000   245000
# ...

# %%
df[df['author'] =='Bill Gates']['views']
# Out:
# 403      1700000
# 789      4600000
# 952      8600000
# 3251    43000000
# 3878     4500000
# 4560     2100000
# 4824     8100000
# 5062     5200000
# Name: views, dtype: int64

# %%
df[df['author'] =='Bill Gates']['views'].mean()
# Out:
# 9725000.0

# %%
df['author'].describe()
# Out:
# count             5439
# unique            4443
# top       Alex Gendler
# freq                45
# Name: author, dtype: object

# %%
df[df['author']=='Alex Gender']
# Out:
# Empty DataFrame
# Columns: [title, author, date, views, likes, link, vtl_ratio]
# Index: []

# %%
'space'=='Space'.lower()
# Out:
# True

# %%
topic='space'
for i in range(len(data)):
    if(topic in data[i][0].lower()):
        print(data[i])
# Out:
# ['How film captures the space between hope and despair' 'Mounia Akl'
#  'December 2021' 628000 18000
#  'https://ted.com/talks/mounia_akl_how_film_captures_the_space_between_hope_and_despair']
# ['Yes, scientists are actually building an elevator to space'
#  'Fabio Pacucci' 'December 2021' 714000 21000
#  'https://ted.com/talks/fabio_pacucci_yes_scientists_are_actually_building_an_elevator_to_space']
# ['Documentary films that explore trauma — and make space for healing'
#  'Almudena Toral' 'May 2021' 1700000 52000
#  'https://ted.com/talks/almudena_toral_documentary_films_that_explore_trauma_and_make_space_for_healing']
# ['What should humans take to space (and leave behind)?'
#  'Jorge Mañes Rubio' 'May 2021' 1500000 47000
#  'https://ted.com/talks/jorge_manes_rubio_what_should_humans_take_to_space_and_leave_behind']
# ['Playful, wondrous public spaces built for community and possibility'
#  'Matthew Mazzotta' 'May 2021' 1200000 37000
# ...

# %%
topic='politics'
for i in range(len(data)):
    if(topic in data[i][0].lower()):
        print(data[i])
# Out:
# [" US politics isn't broken. It's fixed" 'Katherine M. Gehl'
#  'December 2020' 1200000 38000
#  'https://ted.com/talks/katherine_m_gehl_us_politics_isn_t_broken_it_s_fixed']
# ['Do politics make us irrational?' 'Jay Van Bavel' 'February 2020' 544000
#  16000
#  'https://ted.com/talks/jay_van_bavel_do_politics_make_us_irrational']
# ['Michael Tubbs on politics as a force for good' 'The TED Interview'
#  'October 2019' 8600 259
#  'https://ted.com/talks/the_ted_interview_michael_tubbs_on_politics_as_a_force_for_good']
# ['What happened when we paired up thousands of strangers to talk politics'
#  'Jochen Wegner' 'July 2019' 1900000 58000
#  'https://ted.com/talks/jochen_wegner_what_happened_when_we_paired_up_thousands_of_strangers_to_talk_politics']
# ['How to use family dinner to teach politics' 'Hajer Sharief' 'July 2019'
#  3600000 110000
#  'https://ted.com/talks/hajer_sharief_how_to_use_family_dinner_to_teach_politics']
# ...

# %%
topic='education'
for i in range(len(data)):
    if(topic in data[i][0].lower()):
        print(data[i])
# Out:
# ['Sex education should start with consent' ' Kaz' 'December 2021' 649000
#  19000 'https://ted.com/talks/kaz_sex_education_should_start_with_consent']
# ['Education is a fundamental right for every child' 'Makhtoum Abdalla'
#  'December 2021' 1000000 32000
#  'https://ted.com/talks/makhtoum_abdalla_education_is_a_fundamental_right_for_every_child']
# ['3 ways to lower the barriers to higher education' 'Adrian K. Haugabrook'
#  'August 2021' 1100000 34000
#  'https://ted.com/talks/adrian_k_haugabrook_3_ways_to_lower_the_barriers_to_higher_education']
# ['What COVID-19 revealed about US schools — and 4 ways to rethink education'
#  'Nora Flanagan' 'June 2020' 1600000 48000
#  'https://ted.com/talks/nora_flanagan_what_covid_19_revealed_about_us_schools_and_4_ways_to_rethink_education']
# ['Rethinking education and celebrating the Arabic language'
#  'Ahmad M. Hasnah' 'June 2020' 3900 117
#  'https://ted.com/talks/ahmad_m_hasnah_rethinking_education_and_celebrating_the_arabic_language']
# ...

# %% [markdown]
# #### Top TED TALKS  Based on Views

# %%
df.sort_values(by='views')
# Out:
#                                                   title  \
# 613                  Post-Pandemic Paradise in Rapa Nui
# 552                                      Virtual Worlds
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 478                           The case for public media
# ...                                                 ...
# 4605                         The power of vulnerability
# 4765                   How great leaders inspire action
# 2958         Inside the mind of a master procrastinator
# 4084           Your body language may shape who you are
# 5436                        Do schools kill creativity?
#
#                                 author            date     views    likes  \
# 613                          Far Flung    October 2020      1200       37
# 552                          Far Flung   November 2020      1300       39
# ...

# %%
df.sort_values(by='views',ascending=False)
# Out:
#                                                   title  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4765                   How great leaders inspire action
# 4605                         The power of vulnerability
# ...                                                 ...
# 478                           The case for public media
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 552                                      Virtual Worlds
# 613                  Post-Pandemic Paradise in Rapa Nui
#
#                                 author            date     views    likes  \
# 5436                  Sir Ken Robinson   February 2006  72000000  2100000
# 4084                         Amy Cuddy       June 2012  64000000  1900000
# ...

# %%
data=df.values

# %%
data
# Out:
# array([['Climate action needs new frontline leadership',
#         'Ozawa Bineshi Albert', 'December 2021', 404000, 12000,
#         'https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership'],
#        ['The dark history of the overthrow of Hawaii', 'Sydney Iaukea',
#         'February 2022', 214000, 6400,
#         'https://ted.com/talks/sydney_iaukea_the_dark_history_of_the_overthrow_of_hawaii'],
#        ['How play can spark new ideas for your business',
#         'Martin Reeves', 'September 2021', 412000, 12000,
#         'https://ted.com/talks/martin_reeves_how_play_can_spark_new_ideas_for_your_business'],
#        ...,
#        ['Greening the ghetto', 'Majora Carter', 'February 2006', 2900000,
#         88000, 'https://ted.com/talks/majora_carter_greening_the_ghetto'],
#        ['Simplicity sells', 'David Pogue', 'February 2006', 2000000,
#         60000, 'https://ted.com/talks/david_pogue_simplicity_sells'],
# ...

# %%
for i in range(len(data)):
    print(data[i][2])
# Out:
# December 2021
# February 2022
# September 2021
# October 2021
# October 2021
# October 2021
# February 2022
# August 2021
# February 2022
# March 2019
# August 2021
# February 2022
# January 2022
# October 2021
# October 2021
# December 2021
# February 2022
# October 2021
# February 2022
# October 2021
# October 2021
# September 2021
# February 2022
# October 2021
# August 2021
# November 2021
# February 2022
# December 2021
# January 2022
# October 2021
# December 2021
# January 2022
# July 2021
# December 2021
# October 2021
# January 2022
# December 2021
# August 2021
# December 2021
# September 2021
# January 2022
# October 2021
# November 2021
# January 2022
# August 2021
# December 2021
# August 2021
# January 2022
# August 2021
# January 2022
# June 2021
# January 2022
# October 2021
# October 2021
# August 2021
# September 2021
# November 2021
# March 2021
# January 2022
# September 2021
# October 2021
# January 2022
# January 2022
# December 2021
# April 2021
# October 2021
# ...

# %%
df.sort_values(by='views',ascending=False).head(10)
# Out:
#                                                   title            author  \
# 5436                        Do schools kill creativity?  Sir Ken Robinson
# 4084           Your body language may shape who you are         Amy Cuddy
# 2958         Inside the mind of a master procrastinator         Tim Urban
# 4765                   How great leaders inspire action       Simon Sinek
# 4605                         The power of vulnerability       Brené Brown
# 3504         How to speak so that people want to listen   Julian Treasure
# 2168                     My philosophy for a happy life         Sam Berns
# 3251                 The next outbreak? We're not ready        Bill Gates
# 3017  What makes a good life? Lessons from the longe...  Robert Waldinger
# 3994  Looks aren't everything. Believe me, I'm a model.   Cameron Russell
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# ...

# %%
view_to_like=[]
data=df.values

# %%
data[1000]
# Out:
# array(['Vultures: The acid-puking, plague-busting heroes of the ecosystem',
#        'Kenny Coogan', 'February 2020', 1200000, 36000,
#        'https://ted.com/talks/kenny_coogan_vultures_the_acid_puking_plague_busting_heroes_of_the_ecosystem'],
#       dtype=object)

# %% [markdown]
# ##### Top 10 views with most view to like ratio

# %%
view_to_like=[]
data=df.values
for i in range(len(data)):
    view_to_like.append(round(data[i][3]/data[i][4],2))
df['VTL_Ratio']=view_to_like
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_11064\1188004478.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['VTL_Ratio']=view_to_like

# %%
df.sort_values(by='VTL_Ratio',ascending=False).head(10)
# Out:
#                                                   title  \
# 955                A camera that can see around corners
# 905                      What's the point(e) of ballet?
# 837   How to see more and care less: The art of Geor...
# 26    Can you outsmart the fallacy that divided a na...
# 1016             The function and fashion of eyeglasses
# 3089             How computers translate human language
# 4389                            The right to understand
# 4362                           How to topple a dictator
# 5129                                         On glamour
# 3335                     Your strategy needs a strategy
#
#                      author           date   views  likes  \
# 955           David Lindell  November 2019  364000  10000
# 905               Ming Luke     April 2020  364000  10000
# 837        Iseult Gillespie      June 2020  364000  10000
# 26            Elizabeth Cox  February 2022  363000  10000
# ...

# %% [markdown]
# ### TOP 10 Authors with the most number of ted talks

# %%
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link  VTL_Ratio
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...      33.67
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...      33.44
# 2  https://ted.com/talks/martin_reeves_how_play_c...      34.33
# ...

# %%
df.groupby('author').size().sort_values
# Out:
# <bound method Series.sort_values of author
#  B.E.A.T. NYC           1
#  Beautyrest             1
#  Belle and Sebastian    1
#  Butterscotch           1
#  Climbing PoeTree       1
#                        ..
# eL Seed                 2
# iO Tillett Wright       1
# monday.com              1
# tobacco brown           1
# Özlem Cekic             1
# Length: 4443, dtype: int64>

# %%
df.groupby('author').size().sort_values(ascending=False).head(10)
# Out:
# author
# Alex Gendler        45
# Iseult Gillespie    33
# Matt Walker         18
# Alex Rosenthal      15
# Elizabeth Cox       13
# Emma Bryce          12
# Daniel Finkel       11
# Juan Enriquez       11
# Dan Finkel           9
# Hans Rosling         9
# dtype: int64

# %%
df['date']
# Out:
# 0        December 2021
# 1        February 2022
# 2       September 2021
# 3         October 2021
# 4         October 2021
#              ...
# 5435     February 2006
# 5436     February 2006
# 5437     February 2006
# 5438     February 2006
# 5439     February 2006
# Name: date, Length: 5439, dtype: object

# %% [markdown]
# H

# %%
data=df.values
data
# Out:
# array([['Climate action needs new frontline leadership',
#         'Ozawa Bineshi Albert', 'December 2021', 404000, 12000,
#         'https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership'],
#        ['The dark history of the overthrow of Hawaii', 'Sydney Iaukea',
#         'February 2022', 214000, 6400,
#         'https://ted.com/talks/sydney_iaukea_the_dark_history_of_the_overthrow_of_hawaii'],
#        ['How play can spark new ideas for your business',
#         'Martin Reeves', 'September 2021', 412000, 12000,
#         'https://ted.com/talks/martin_reeves_how_play_can_spark_new_ideas_for_your_business'],
#        ...,
#        ['Greening the ghetto', 'Majora Carter', 'February 2006', 2900000,
#         88000, 'https://ted.com/talks/majora_carter_greening_the_ghetto'],
#        ['Simplicity sells', 'David Pogue', 'February 2006', 2000000,
#         60000, 'https://ted.com/talks/david_pogue_simplicity_sells'],
# ...

# %%
data=df.values
data
for i in range(len(data)):
    print(data[i][2])
# Out:
# December 2021
# February 2022
# September 2021
# October 2021
# October 2021
# October 2021
# February 2022
# August 2021
# February 2022
# March 2019
# August 2021
# February 2022
# January 2022
# October 2021
# October 2021
# December 2021
# February 2022
# October 2021
# February 2022
# October 2021
# October 2021
# September 2021
# February 2022
# October 2021
# August 2021
# November 2021
# February 2022
# December 2021
# January 2022
# October 2021
# December 2021
# January 2022
# July 2021
# December 2021
# October 2021
# January 2022
# December 2021
# August 2021
# December 2021
# September 2021
# January 2022
# October 2021
# November 2021
# January 2022
# August 2021
# December 2021
# August 2021
# January 2022
# August 2021
# January 2022
# June 2021
# January 2022
# October 2021
# October 2021
# August 2021
# September 2021
# November 2021
# March 2021
# January 2022
# September 2021
# October 2021
# January 2022
# January 2022
# December 2021
# April 2021
# October 2021
# ...

# %%
'December 2021'.split(' ')
# Out:
# ['December', '2021']

# %%
data=df.values
data
for i in range(len(data)):
    print(data[i][2].split(' '))
# Out:
# ['December', '2021']
# ['February', '2022']
# ['September', '2021']
# ['October', '2021']
# ['October', '2021']
# ['October', '2021']
# ['February', '2022']
# ['August', '2021']
# ['February', '2022']
# ['March', '2019']
# ['August', '2021']
# ['February', '2022']
# ['January', '2022']
# ['October', '2021']
# ['October', '2021']
# ['December', '2021']
# ['February', '2022']
# ['October', '2021']
# ['February', '2022']
# ['October', '2021']
# ['October', '2021']
# ['September', '2021']
# ['February', '2022']
# ['October', '2021']
# ['August', '2021']
# ['November', '2021']
# ['February', '2022']
# ['December', '2021']
# ['January', '2022']
# ['October', '2021']
# ['December', '2021']
# ['January', '2022']
# ['July', '2021']
# ['December', '2021']
# ['October', '2021']
# ['January', '2022']
# ['December', '2021']
# ['August', '2021']
# ['December', '2021']
# ['September', '2021']
# ['January', '2022']
# ['October', '2021']
# ['November', '2021']
# ['January', '2022']
# ...

# %%
month=[]
year=[]

for i in range(len(data)):
    month.append(data[i][2].split(' ')[0])
    year.append(data[i][2].split(' ')[1])

# %%
month
# Out:
# ['December',
#  'February',
#  'September',
#  'October',
#  'October',
#  'October',
#  'February',
#  'August',
#  'February',
#  'March',
#  'August',
#  'February',
#  'January',
#  'October',
#  'October',
#  'December',
#  'February',
#  'October',
#  'February',
#  'October',
#  'October',
#  'September',
#  'February',
#  'October',
#  'August',
#  'November',
#  'February',
#  'December',
#  'January',
#  'October',
#  'December',
#  'January',
#  'July',
#  'December',
#  'October',
#  'January',
#  'December',
#  'August',
#  'December',
#  'September',
#  'January',
#  'October',
#  'November',
#  'January',
#  'August',
#  'December',
#  'August',
#  'January',
#  'August',
#  'January',
#  'June',
#  'January',
#  'October',
#  'October',
#  'August',
#  'September',
#  'November',
#  'March',
#  'January',
#  'September',
#  'October',
#  'January',
#  'January',
#  'December',
#  'April',
#  'October',
#  'December',
#  'December',
#  'December',
#  'August',
# ...

# %%
year
# Out:
# ['2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2022',
#  '2019',
#  '2021',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2022',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2022',
#  '2021',
#  '2021',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
# ...

# %%
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %%
df['year']=year
df['month']=month
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_15352\3940076646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=year
# C:\Users\R\AppData\Local\Temp\ipykernel_15352\3940076646.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month']=month

# %%
df[df['year']==2020]
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link  year      month
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...  2021   December
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...  2022   February
# 2  https://ted.com/talks/martin_reeves_how_play_c...  2021  September
# ...

# %%
df[df['year']==2021]
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link  year      month
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...  2021   December
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...  2022   February
# 2  https://ted.com/talks/martin_reeves_how_play_c...  2021  September
# ...

# %%
len(df[df['year']=='2021'])
# Out:
# 390

# %%
len(df[df['year']=='2020'])
# Out:
# 501

# %% [markdown]
# ###  Trend of TED TALKS Frequency by years

# %%
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link  year      month
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...  2021   December
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...  2022   February
# 2  https://ted.com/talks/martin_reeves_how_play_c...  2021  September
# ...

# %%
df.groupby('year').size()
# Out:
# year
# 1970      2
# 1972      1
# 1983      1
# 1984      1
# 1990      1
# 1991      1
# 1994      1
# 1998      6
# 2001      5
# 2002     26
# 2003     34
# 2004     33
# 2005     65
# 2006     49
# 2007    113
# 2008     84
# 2009    233
# 2010    267
# 2011    271
# 2012    302
# 2013    388
# 2014    357
# 2015    376
# 2016    399
# 2017    495
# 2018    473
# 2019    544
# 2020    501
# 2021    390
# 2022     20
# dtype: int64

# %%
df.groupby('year').size().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df.groupby('year').size().plot(kind='pie')
# Out:
# <Axes: >

# %%
df.groupby('year').size().plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.groupby('month').size().plot(kind='pie')
# Out:
# <Axes: >

# %%
df.groupby('month').size().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.groupby('month').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('month').size().sort_values(ascending=False).plot(kind='barh')
# Out:
# <Axes: ylabel='month'>

# %%
df_pr=df[df['year']=='2020']
df_pr.groupby('month').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
df_pr=df[df['year']=='2021']
df_pr.groupby('month').size().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
df_pr=df[df['year']=='2020']
df_pr.groupby('month').size().sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: >

# %%
df_pr=df[df['year']=='2021']
df_pr.groupby('month').size().sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: >

# %%
df.groupby('author').sum()['views'].sort_values(ascending=False).head(10)
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_15352\4149226553.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('author').sum()['views'].sort_values(ascending=False).head(10)
# author
# Alex Gendler        187196000
# Sir Ken Robinson     95654000
# Bill Gates           77800000
# Simon Sinek          74800000
# Brené Brown          72000000
# Julian Treasure      64300000
# Amy Cuddy            64000000
# Tim Urban            60000000
# Iseult Gillespie     54998000
# Mia Nacamulli        44174000
# Name: views, dtype: int64

# %%
df.groupby('author').mean()['views'].sort_values(ascending=False).head(10)
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_15352\4191297521.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('author').mean()['views'].sort_values(ascending=False).head(10)
# author
# Amy Cuddy           64000000.0
# Tim Urban           60000000.0
# Sam Berns           43000000.0
# Robert Waldinger    41000000.0
# Cameron Russell     38000000.0
# Graham Shaw         37000000.0
# Mary Roach          37000000.0
# Brené Brown         36000000.0
# Tom Thum            34000000.0
# Pamela Meyer        31000000.0
# Name: views, dtype: float64
